# %%
import pandas as pd

# %%
data = pd.read_csv('brain_fimo.tsv', sep='\t')

# %%
pd.value_counts(data.motif_id)
# Out:
# /var/folders/dy/3708l0gn12z7ns1f72f3c9bw0000gn/T/ipykernel_34446/636329411.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(data.motif_id)
# motif_id
# MA1107.2                                                                                                               1999
# MA1155.1                                                                                                               1652
# MA0073.1                                                                                                               1525
# MA0162.4                                                                                                               1509
# MA0508.3                                                                                                                979
# ...

# %%
df = data[data['q-value'] < 0.05]

# %%
df.iloc[:10]
# Out:
#    motif_id motif_alt_id        sequence_name  start  stop strand    score  \
# 0  MA1643.1         NFIB  25_36738367_C_T_ref    2.0  22.0      -  26.4388
# 1  MA1643.1         NFIB  25_36738367_C_T_alt    2.0  22.0      -  26.4388
# 2  MA1528.1  NFIX(var.2)  25_36738367_C_T_ref    4.0  20.0      +  22.8980
# 3  MA1528.1  NFIX(var.2)  25_36738367_C_T_alt    4.0  20.0      +  22.8980
# 4  MA1527.1  NFIC(var.2)  25_36738367_C_T_alt    4.0  20.0      +  23.2931
# 5  MA1527.1  NFIC(var.2)  25_36738367_C_T_ref    4.0  20.0      +  23.2931
# 6  MA0119.1   NFIC::TLX1  25_36738367_C_T_ref    5.0  18.0      -  23.3265
# 7  MA0119.1   NFIC::TLX1  25_36738367_C_T_alt    5.0  18.0      -  23.3265
# 8  MA0139.1         CTCF   6_41396825_C_T_ref   39.0  57.0      -  23.1475
# 9  MA0139.1         CTCF   6_41396825_C_T_alt   39.0  57.0      -  23.1475
#
#         p-value   q-value       matched_sequence
# 0  2.570000e-10  0.000071  AGCCTGGCACCGTGCCAAGGC
# ...
